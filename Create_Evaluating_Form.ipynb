# %% [markdown]
# <a href="https://colab.research.google.com/github/imnawar/thesis_repo/blob/main/Create_Evaluating_Form.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 60.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 65.1 MB/s eta 0:00:00
# ...

# %%
# !pip install pyngrok

# %%
from pyngrok import ngrok
public_url = ngrok.connect(8501)
print(public_url)
# Out:
# ERROR:pyngrok.process.ngrok:t=2026-05-02T21:59:56+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ERROR:pyngrok.process.ngrok:t=2026-05-02T21:59:56+0000 lvl=eror msg="session closing" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ---------------------------------------------------------------------------
# PyngrokNgrokError                         Traceback (most recent call last)
# /tmp/ipykernel_10900/1805073378.py in <cell line: 0>()
#       1 from pyngrok import ngrok
# ...

# %%
import streamlit as st
import pandas as pd
import random
from datetime import datetime

# 🔹 Load dataset
df = pd.read_csv("/content/drive/MyDrive/MasterThises/fake_news_with_images.csv")

# 🔹 Shuffle data
if "index" not in st.session_state:
    st.session_state.index = random.randint(0, len(df)-1)

row = df.iloc[st.session_state.index]

row = df.iloc[st.session_state.index]

st.title("📰 News Evaluation")

# 🔹 Title
st.subheader(row["fake_title"])

# 🔹 Image
if pd.notna(row["generated_image_path"]):
    st.image(row["generated_image_path"], use_column_width=True)

# 🔹 Caption
if pd.notna(row["fake_caption"]):
    st.caption(row["fake_caption"])

# 🔹 User question
st.markdown("### Do you think this news is real or fake?")

choice = st.radio(
    "Select one:",
    ["Real", "Fake"]
)

# 🔹 Submit button
if st.button("Submit"):
    result = {
        "index": st.session_state.index,
        "prediction": choice,
        "true_label": row.get("label", "unknown"),
        "timestamp": datetime.now()
    }

    # save results
    results_df = pd.DataFrame([result])

    try:
        old = pd.read_csv("results.csv")
        results_df = pd.concat([old, results_df], ignore_index=True)
    except:
        pass

    results_df.to_csv("results.csv", index=False)

    st.success("Response saved!")

    # move to next sample
    st.session_state.index = random.randint(0, len(df)-1)
    st.rerun()
# Out:
# 2026-05-02 22:03:18.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-02 22:03:18.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-02 22:03:18.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-02 22:03:18.249 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-02 22:03:18.250 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-02 22:03:18.251 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-02 22:03:18.252 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
# 3DBdvPjXoJnw6TnYKx7QtSFAd0g_2WyYMB5QxQ3aji3XXTbqV

# %%
from pyngrok import ngrok

ngrok.set_auth_token("3DBdvPjXoJnw6TnYKx7QtSFAd0g_2WyYMB5QxQ3aji3XXTbqV")

# %%
public_url = ngrok.connect(8501)
print(public_url)
# Out:
# NgrokTunnel: "https://shifty-xbox-runner.ngrok-free.dev" -> "http://localhost:8501"

# %%
# !cat /content/logs.txt
# Out:
# Usage: streamlit run [OPTIONS] [TARGET] [ARGS]...
# Try 'streamlit run --help' for help.
#
# Error: Invalid value: File does not exist: app.py

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd

st.title("📰 News Evaluation")

st.write("If you see this, Streamlit works 🎉")
# Out:
# Writing app.py

# %%
# !streamlit run app.py --server.port 8501 --server.address 0.0.0.0 &>/content/logs.txt &

# %%
from pyngrok import ngrok

ngrok.kill()
public_url = ngrok.connect(8501)
print(public_url)
# Out:
# NgrokTunnel: "https://shifty-xbox-runner.ngrok-free.dev" -> "http://localhost:8501"

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import os
import random
from datetime import datetime

st.title("📰 Fake News Evaluation")

# 🔹 Load dataset
df = pd.read_csv("/content/drive/MyDrive/MasterThises/fake_news_with_images.csv")

# 🔹 Random index (store in session)
if "index" not in st.session_state:
    st.session_state.index = random.randint(0, len(df)-1)

row = df.iloc[st.session_state.index]

# 🔹 Display title
st.subheader(row["fake_title"])

# 🔹 Display image
img_path = row["generated_image_path"]

if pd.notna(img_path) and os.path.exists(img_path):
    st.image(img_path)
else:
    st.warning(f"Image not found: {img_path}")

# 🔹 Display caption
if pd.notna(row["fake_caption"]):
    st.caption(row["fake_caption"])

# 🔹 Question
st.markdown("### Do you think this news is real or fake?")

choice = st.radio("Select one:", ["Real", "Fake"])

# 🔹 Submit
if st.button("Submit"):
    result = {
        "index": st.session_state.index,
        "prediction": choice,
        "timestamp": datetime.now()
    }

    # 🔹 Save results
    result_df = pd.DataFrame([result])

    try:
        old = pd.read_csv("results.csv")
        result_df = pd.concat([old, result_df], ignore_index=True)
    except:
        pass

    result_df.to_csv("results.csv", index=False)

    st.success("Saved!")

    # 🔹 Move to next sample
    st.session_state.index = random.randint(0, len(df)-1)
    st.rerun()
# Out:
# Overwriting app.py

# %%
# !streamlit run app.py --server.port 8501 --server.address 0.0.0.0 &>/content/logs.txt &

# %%
from pyngrok import ngrok

ngrok.kill()
public_url = ngrok.connect(8501)
print(public_url)
# Out:
# NgrokTunnel: "https://shifty-xbox-runner.ngrok-free.dev" -> "http://localhost:8501"

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import os
import random
from datetime import datetime

st.set_page_config(page_title="تقييم الأخبار", layout="centered")

st.title("📰 تقييم مصداقية الأخبار")

# 🔹 Load dataset
df = pd.read_csv("/content/drive/MyDrive/MasterThises/fake_news_with_images.csv")

MAX_SAMPLES = min(50, len(df))

# 🔹 Session state
if "indices" not in st.session_state:
    st.session_state.indices = random.sample(range(len(df)), MAX_SAMPLES)
    st.session_state.current = 0

# 🔹 Current item
current_pos = st.session_state.current
current_idx = st.session_state.indices[current_pos]
row = df.iloc[current_idx]

# 🔹 Progress
progress = (current_pos + 1) / MAX_SAMPLES
st.progress(progress)

st.markdown(f"### 🧾 الخبر رقم {current_pos + 1} / {MAX_SAMPLES}")

# 🔹 Title
st.subheader(row["fake_title"])

# 🔹 Image
img_path = row["generated_image_path"]

if pd.notna(img_path) and os.path.exists(img_path):
    st.image(img_path)
else:
    st.warning("⚠️ الصورة غير موجودة")

# 🔹 Caption
if pd.notna(row["fake_caption"]):
    st.caption(row["fake_caption"])

# 🔹 Question
st.markdown("### ما مدى مصداقية هذا الخبر؟")

rating = st.slider(
    "التقييم: (1=مزيف، 5=حقيقي)",
    min_value=1,
    max_value=5,
    value=3,
    help="1 = مزيف تمامًا، 5 = حقيقي تمامًا"
)

# # 🔹 Confidence
# confidence = st.slider(
#     "ما مدى ثقتك في تقييمك؟",
#     min_value=1,
#     max_value=5,
#     value=3
# )

# 🔹 Submit
if st.button("إرسال"):
    result = {
        "sample_index": current_idx,
        "order": current_pos,
        "rating": rating,
        # "confidence": confidence,
        "timestamp": datetime.now()
    }

    result_df = pd.DataFrame([result])

    try:
        old = pd.read_csv("results.csv")
        result_df = pd.concat([old, result_df], ignore_index=True)
    except:
        pass

    result_df.to_csv("results.csv", index=False)

    st.success("✅ تم حفظ التقييم")

    # 🔹 Next sample
    st.session_state.current += 1

    if st.session_state.current >= MAX_SAMPLES:
        st.balloons()
        st.success("🎉 انتهيت من التقييم، شكرًا لك!")
    else:
        st.rerun()
# Out:
# Overwriting app.py

# %%
# !pkill -f streamlit

# %%
# !streamlit run app.py --server.port 8501 --server.address 0.0.0.0 &>/content/logs.txt &

# %%
from pyngrok import ngrok

ngrok.kill()  # stop old tunnel
public_url = ngrok.connect(8501)
print(public_url)
# Out:
# NgrokTunnel: "https://shifty-xbox-runner.ngrok-free.dev" -> "http://localhost:8501"

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import os
import random
import uuid
from datetime import datetime

st.set_page_config(page_title="تقييم الأخبار", layout="centered")

st.title("📰 تقييم مصداقية الأخبار")

# =========================
# 🔹 Auto-generated user ID
# =========================
if "user_id" not in st.session_state:
    st.session_state.user_id = f"user_{str(uuid.uuid4())[:8]}"

user_id = st.session_state.user_id
st.markdown(f"👤 المستخدم الحالي: `{user_id}`")

# =========================
# 🔹 Load dataset
# =========================
df = pd.read_csv("/content/drive/MyDrive/MasterThises/fake_news_with_images.csv")

MAX_SAMPLES = min(25, len(df))

# =========================
# 🔹 Session state setup
# =========================
if "indices" not in st.session_state:
    st.session_state.indices = random.sample(range(len(df)), MAX_SAMPLES)
    st.session_state.current = 0

# =========================
# 🔹 Current sample
# =========================
current_pos = st.session_state.current
current_idx = st.session_state.indices[current_pos]
row = df.iloc[current_idx]

# =========================
# 🔹 Progress bar
# =========================
progress = (current_pos + 1) / MAX_SAMPLES
st.progress(progress)

st.markdown(f"### 🧾 الخبر رقم {current_pos + 1} / {MAX_SAMPLES}")

# =========================
# 🔹 Display content
# =========================
st.subheader(row["fake_title"])

img_path = row["generated_image_path"]

if pd.notna(img_path) and os.path.exists(img_path):
    st.image(img_path)
else:
    st.warning("⚠️ الصورة غير موجودة")

if pd.notna(row["fake_caption"]):
    st.caption(row["fake_caption"])

# =========================
# 🔹 Rating
# =========================
st.markdown("### ما مدى مصداقية هذا الخبر؟")

rating = st.slider(
    "التقييم (1 = مزيف، 5 = حقيقي):",
    min_value=1,
    max_value=5,
    value=3
)

# =========================
# 🔹 Submit
# =========================
if st.button("إرسال"):
    now = datetime.now()

    result = {
        "user_id": user_id,
        "date": now.date().isoformat(),
        "time": now.strftime("%H:%M:%S"),

        "sample_index": current_idx,
        "order": current_pos,

        "title": row["fake_title"],
        "caption": row["fake_caption"],
        "image_path": row["generated_image_path"],

        "rating": rating
    }

    df_result = pd.DataFrame([result])

    # 🔹 Save per user file
    file_name = f"results_{user_id}.csv"

    try:
        old = pd.read_csv(file_name)
        df_result = pd.concat([old, df_result], ignore_index=True)
    except:
        pass

    df_result.to_csv("/content/drive/MyDrive/MasterThises/"+file_name, index=False)

    st.success("✅ تم حفظ التقييم بنجاح")

    # =========================
    # 🔹 Next sample
    # =========================
    st.session_state.current += 1

    if st.session_state.current >= MAX_SAMPLES:
        st.balloons()
        st.success("🎉 انتهى التقييم، شكرًا لمشاركتك!")
    else:
        st.rerun()
# Out:
# Overwriting app.py

# %%
# !pkill -f streamlit

# %%
# !streamlit run app.py --server.port 8501 --server.address 0.0.0.0 &>/content/logs.txt &

# %%
from pyngrok import ngrok

ngrok.kill()  # stop old tunnel
public_url = ngrok.connect(8501)
print(public_url)
# Out:
# NgrokTunnel: "https://shifty-xbox-runner.ngrok-free.dev" -> "http://localhost:8501"

# %%
# /content/drive/MyDrive/MasterThises/generated_images_manipulated_titles_morining_expr

# %%
# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 45.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 55.0 MB/s eta 0:00:00
# ...

# %%
# !pip install pyngrok

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import os
import random
import uuid
from datetime import datetime

st.set_page_config(page_title="تقييم الأخبار", layout="centered")

st.title("📰 تقييم مصداقية الأخبار")

# =========================
# 🔹 Auto-generated user ID
# =========================
if "user_id" not in st.session_state:
    st.session_state.user_id = f"user_{str(uuid.uuid4())[:8]}"

user_id = st.session_state.user_id
st.markdown(f"👤 المستخدم الحالي: `{user_id}`")

# =========================
# 🔹 Load dataset
# =========================
df = pd.read_csv("/content/drive/MyDrive/MasterThises/generated_images_manipulated_titles_morining_expr/manipulated_titles.csv")
df.dropna(inplace=True)

MAX_SAMPLES = min(10, len(df))

# =========================
# 🔹 Session state setup
# =========================
if "indices" not in st.session_state:
    st.session_state.indices = random.sample(range(len(df)), MAX_SAMPLES)
    st.session_state.current = 0

# =========================
# 🔹 Current sample
# =========================
current_pos = st.session_state.current
current_idx = st.session_state.indices[current_pos]
row = df.iloc[current_idx]

# =========================
# 🔹 Progress bar
# =========================
progress = (current_pos + 1) / MAX_SAMPLES
st.progress(progress)

st.markdown(f"### 🧾 الخبر رقم {current_pos + 1} / {MAX_SAMPLES}")

# =========================
# 🔹 Display content
# =========================
st.subheader(row["fake_title"])

img_path = row["generated_image_path"]

if pd.notna(img_path) and os.path.exists(img_path):
    st.image(img_path)
else:
    st.warning("⚠️ الصورة غير موجودة")

if pd.notna(row["fake_caption"]):
    st.caption(row["fake_caption"])

# =========================
# 🔹 Rating
# =========================
st.markdown("### ما مدى مصداقية هذا الخبر؟")

rating = st.slider(
    "التقييم (1 = مزيف، 5 = حقيقي):",
    min_value=1,
    max_value=5,
    value=3
)

# =========================
# 🔹 Submit
# =========================
if st.button("إرسال"):
    now = datetime.now()

    result = {
        "user_id": user_id,
        "date": now.date().isoformat(),
        "time": now.strftime("%H:%M:%S"),

        "sample_index": current_idx,
        "order": current_pos,

        "title": row["fake_title"],
        "caption": row["fake_caption"],
        "image_path": row["generated_image_path"],

        "rating": rating
    }

    df_result = pd.DataFrame([result])

    # 🔹 Save per user file
    file_name = f"results_{user_id}.csv"

    try:
        old = pd.read_csv(file_name)
        df_result = pd.concat([old, df_result], ignore_index=True)
    except:
        pass

    df_result.to_csv("/content/drive/MyDrive/MasterThises/generated_images_manipulated_titles_morining_expr/"+file_name, index=False)

    st.success("✅ تم حفظ التقييم بنجاح")

    # =========================
    # 🔹 Next sample
    # =========================
    st.session_state.current += 1

    if st.session_state.current >= MAX_SAMPLES:
        st.balloons()
        st.success("🎉 انتهى التقييم، شكرًا لمشاركتك!")
    else:
        st.rerun()
# Out:
# Writing app.py

# %%
# !pkill -f streamlit

# %%
# !streamlit run app.py --server.port 8501 --server.address 0.0.0.0 &>/content/logs.txt &

# %%
from pyngrok import ngrok
from pyngrok import ngrok

ngrok.set_auth_token("3DBdvPjXoJnw6TnYKx7QtSFAd0g_2WyYMB5QxQ3aji3XXTbqV")
# public_url = ngrok.connect(8501)
# print(public_url)
ngrok.kill()  # stop old tunnel
public_url = ngrok.connect(8501)
print(public_url)
# Out:
# NgrokTunnel: "https://shifty-xbox-runner.ngrok-free.dev" -> "http://localhost:8501"

# %%
# !pkill -f streamlit

# %%
from pyngrok import ngrok
ngrok.kill()

# %%
# !streamlit run app.py --server.port 8501 --server.address 0.0.0.0 &>/content/logs.txt &

# %%
# !cat /content/logs.txt

# %%
from pyngrok import ngrok

public_url = ngrok.connect(8501)
print(public_url)
# Out:
# NgrokTunnel: "https://shifty-xbox-runner.ngrok-free.dev" -> "http://localhost:8501"

# %% [markdown]
# Update week3 meeting

# %%
# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 20.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 46.4 MB/s eta 0:00:00
# ...

# %%
# !pip install pyngrok

# %%
# %%writefile app.py

import streamlit as st
import pandas as pd
import os
import random
import uuid

st.set_page_config(page_title="تقييم الأخبار", layout="centered")

st.title("📰 تقييم مصداقية الأخبار")

# ==========================================
# 🔹 CONFIG
# ==========================================
CSV_PATH = "/content/drive/MyDrive/MasterThises/fake_generated_images/generated_image_dataset.csv"

MAX_IMAGES_PER_USER = 25

# ==========================================
# 🔹 Auto-generated user ID
# ==========================================
if "user_id" not in st.session_state:
    st.session_state.user_id = f"user_{str(uuid.uuid4())[:8]}"

user_id = st.session_state.user_id

st.markdown(f"👤 المستخدم الحالي: `{user_id}`")

# ==========================================
# 🔹 Load dataset
# ==========================================
df = pd.read_csv(CSV_PATH)

# Keep only rows with images
df = df[df["generated_image_path"].notna()]

# ==========================================
# 🔹 Create evaluation columns if missing
# ==========================================
# required_cols = [
#     "eval_1",
#     "eval_2",
#     "eval_3",
#     "user_1",
#     "user_2",
#     "user_3",
#     "eval_count",
#     "final_score"
# ]

# for col in required_cols:

#     if col not in df.columns:

#         if col == "eval_count":
#             df[col] = 0
#         else:
#             df[col] = ""

# ==========================================
# 🔹 Keep rows with < 3 evaluations
# ==========================================
remaining = df[df["eval_count"] < 3]

# ==========================================
# 🔹 Initialize random 25 images for user
# ==========================================
if "assigned_indices" not in st.session_state:

    available_indices = remaining.index.tolist()

    sample_size = min(MAX_IMAGES_PER_USER, len(available_indices))

    st.session_state.assigned_indices = random.sample(
        available_indices,
        sample_size
    )

    st.session_state.current_position = 0

# ==========================================
# 🔹 User completed all assigned images
# ==========================================
if st.session_state.current_position >= len(st.session_state.assigned_indices):

    st.balloons()
    st.success("🎉 انتهى التقييم، شكراً لمشاركتك!")
    st.stop()

# ==========================================
# 🔹 Current image
# ==========================================
current_idx = st.session_state.assigned_indices[
    st.session_state.current_position
]

current_row = df.loc[current_idx]

# ==========================================
# 🔹 Skip if already evaluated 3 times
# ==========================================
if int(current_row["eval_count"]) >= 3:

    st.session_state.current_position += 1
    st.rerun()

# ==========================================
# 🔹 Progress bar
# ==========================================
progress = (
    st.session_state.current_position + 1
) / len(st.session_state.assigned_indices)

st.progress(progress)

st.markdown(
    f"### 🧾 الخبر رقم "
    f"{st.session_state.current_position + 1}"
    f" / {len(st.session_state.assigned_indices)}"
)

# ==========================================
# 🔹 Display title
# ==========================================
st.subheader(current_row["title"])

# ==========================================
# 🔹 Display image
# ==========================================
img_path = current_row["generated_image_path"]

if pd.notna(img_path) and os.path.exists(img_path):
    st.image(img_path)
else:
    st.warning("⚠️ الصورة غير موجودة")

# ==========================================
# 🔹 Display caption
# ==========================================
if (
    "caption" in current_row
    and pd.notna(current_row["caption"])
):
    st.markdown("### 📝 الوصف")
    st.write(current_row["caption"])

# ==========================================
# 🔹 Rating
# ==========================================
st.markdown("### ما مدى مصداقية هذا الخبر؟")

rating = st.slider(
    "التقييم (1 = مزيف، 5 = حقيقي):",
    min_value=1,
    max_value=5,
    value=3
)

# ==========================================
# 🔹 Submit
# ==========================================
if st.button("إرسال"):

    eval_count = int(df.at[current_idx, "eval_count"])

    # --------------------------------------
    # Store evaluations separately
    # --------------------------------------
    if eval_count == 0:

        df.at[current_idx, "eval_1"] = rating
        df.at[current_idx, "user_1"] = user_id

    elif eval_count == 1:

        df.at[current_idx, "eval_2"] = rating
        df.at[current_idx, "user_2"] = user_id

    elif eval_count == 2:

        df.at[current_idx, "eval_3"] = rating
        df.at[current_idx, "user_3"] = user_id

    # --------------------------------------
    # Increment evaluation count
    # --------------------------------------
    df.at[current_idx, "eval_count"] = eval_count + 1

    # --------------------------------------
    # Final average score
    # --------------------------------------
    scores = [
        df.at[current_idx, "eval_1"],
        df.at[current_idx, "eval_2"],
        df.at[current_idx, "eval_3"]
    ]

    valid_scores = [
        s for s in scores
        if pd.notna(s) and s != ""
    ]

    if len(valid_scores) == 3:

        avg_score = sum(map(float, valid_scores)) / 3

        df.at[current_idx, "final_score"] = round(avg_score, 2)
    # --------------------------------------
    # Save updated CSV
    # --------------------------------------
    df.to_csv(CSV_PATH, index=False)

    st.success("✅ تم حفظ التقييم بنجاح")

    # --------------------------------------
    # Move to next image
    # --------------------------------------
    st.session_state.current_position += 1



    st.rerun()
# Out:
# Writing app.py

# %%
# !pkill -f streamlit

# %%
# !streamlit run app.py --server.port 8501 --server.address 0.0.0.0 &>/content/logs.txt &

# %%
from pyngrok import ngrok
ngrok.set_auth_token("3DBdvPjXoJnw6TnYKx7QtSFAd0g_2WyYMB5QxQ3aji3XXTbqV")
# public_url = ngrok.connect(8501)
# print(public_url)
ngrok.kill()  # stop old tunnel
public_url = ngrok.connect(8501)
print(public_url)
# Out:
# NgrokTunnel: "https://shifty-xbox-runner.ngrok-free.dev" -> "http://localhost:8501"

# %%
from pyngrok import ngrok
ngrok.kill()

# %%
import pandas as pd

# ==========================================
# Load evaluated dataset
# ==========================================
CSV_PATH = "/content/drive/MyDrive/MasterThises/fake_generated_images/generated_image_dataset.csv"

df = pd.read_csv(CSV_PATH)

# ==========================================
# Completed evaluations
# ==========================================
completed_df = df[df["eval_count"] >= 3]

print("Completed Images:", len(completed_df))
print()

# ==========================================
# Average final score
# ==========================================
avg_score = completed_df["final_score"].mean()

print("Average Final Score:", round(avg_score, 2))
print()

# ==========================================
# Score distribution
# ==========================================
print("Score Distribution:")
print(completed_df["final_score"].round().value_counts())
print()

# ==========================================
# Show completed images info
# ==========================================
cols_to_show = [
    "title",
    "caption",
    "generated_image_path",
    "eval_1",
    "eval_2",
    "eval_3",
    "final_score"
]

print(completed_df[cols_to_show].head(20))
# Out:
# Completed Images: 20
#
# Average Final Score: 3.65
#
# Score Distribution:
# final_score
# 4.0    8
# 5.0    4
# 2.0    4
# 3.0    4
# Name: count, dtype: int64
#
#                                                  title  \
# 1    انفجار خط أنابيب يوقف حركة القطارات في الإسكند...
# 3    تدشين أول مدرسة تفاعلية في سلطنة عُمان لتعزيز ...
# 52   "الأحياء الشعبية في الجزائر تشهد تزايداً ملحوظ...
# 53   "بحرينية تطلق مبادرة لدعم ذوي الاحتياجات الخاص...
# 68   تفشي ظاهرة التسول في لبنان يثير قلق المجتمع ال...
# 91   الأخضر الشاب يحصد ذهبية كرة اليد في البطولة ال...
# 95   الأردن يطلق مشروعا رائدا في الطاقة الشمسية لتع...
# 99   وزارة الصحة المصرية تطلق حملة توعوية لمكافحة ا...
# 102  الأردن يعلن عن خطة جديدة لتعزيز التعاون التجار...
# 110  المغرب يطلق منصة إلكترونية جديدة لتعزيز الابتك...
# 111  حريق مدمر يلتهم مساحات شاسعة من غابات الريف ال...
# 121  الجزائر تطلق حملة وطنية للتوعية بأهمية الصحة ا...
# 131  الجزائر تحتفل باليوم الوطني للثقافة بفعاليات ف...
# ...

# %%
completed_df[cols_to_show].head(20)
# Out:
#                                                  title  \
# 1    انفجار خط أنابيب يوقف حركة القطارات في الإسكند...
# 3    تدشين أول مدرسة تفاعلية في سلطنة عُمان لتعزيز ...
# 52   "الأحياء الشعبية في الجزائر تشهد تزايداً ملحوظ...
# 53   "بحرينية تطلق مبادرة لدعم ذوي الاحتياجات الخاص...
# 68   تفشي ظاهرة التسول في لبنان يثير قلق المجتمع ال...
# 91   الأخضر الشاب يحصد ذهبية كرة اليد في البطولة ال...
# 95   الأردن يطلق مشروعا رائدا في الطاقة الشمسية لتع...
# 99   وزارة الصحة المصرية تطلق حملة توعوية لمكافحة ا...
# 102  الأردن يعلن عن خطة جديدة لتعزيز التعاون التجار...
# 110  المغرب يطلق منصة إلكترونية جديدة لتعزيز الابتك...
# 111  حريق مدمر يلتهم مساحات شاسعة من غابات الريف ال...
# 121  الجزائر تطلق حملة وطنية للتوعية بأهمية الصحة ا...
# 131  الجزائر تحتفل باليوم الوطني للثقافة بفعاليات ف...
# 135  "تشكيل فرقة فنية جديدة في بغداد لتعزيز الثقافة...
# 146  شجرة الزيتون في تونس.. رمز صمود الأجيال رغم ال...
# 167  الجزائر تحتضن "ماراثون المحبة" لدعم الأيتام وت...
# ...

# %%
import pandas as pd

# ==========================================
# Load dataset
# ==========================================
CSV_PATH = "/content/drive/MyDrive/MasterThises/fake_generated_images/generated_image_dataset.csv"

df = pd.read_csv(CSV_PATH)

# ==========================================
# Ensure correct type
# ==========================================
df["final_score"] = pd.to_numeric(df["final_score"], errors="coerce")

# ==========================================
# Filter: low-rated images (< 3)
# ==========================================
low_score_df = df[df["final_score"] < 3]

print("Number of low-scored images:", len(low_score_df))
print("\n==========================================\n")

# ==========================================
# Print required fields
# ==========================================
for _, row in low_score_df.iterrows():
    print("TITLE:")
    print(row["title"])
    print("\nCAPTION:")
    print(row["caption"])
    print("\nIMAGE PATH:")
    print(row["generated_image_path"])
    print("\nFINAL SCORE:", row["final_score"])
    print("\n------------------------------------------\n")
# Out:
# Number of low-scored images: 5
#
# ...
#
# TITLE:
# تفشي ظاهرة التسول في لبنان يثير قلق المجتمع المحلي
#
# CAPTION:
# مجموعة من المتسولين في شوارع بيروت يعكسون معاناة العديد من الأسر بسبب الأزمات الاقتصادية المستمرة (الجزيرة)
#
# IMAGE PATH:
# /content/drive/MyDrive/MasterThises/fake_generated_images/fake_news_80.png
#
# FINAL SCORE: 2.0
#
# ------------------------------------------
#
# TITLE:
# حريق مدمر يلتهم مساحات شاسعة من غابات الريف المغربي ويثير مخاوف المواطنين
#
# CAPTION:
# فرق الإطفاء تعمل على السيطرة على النيران المشتعلة وسط أشجار الصنوبر الكثيفة في غابات الريف، بينما يتصاعد الدخان الكثيف في السماء (الأناضول)
#
# IMAGE PATH:
# /content/drive/MyDrive/MasterThises/fake_generated_images/fake_news_127.png
#
# FINAL SCORE: 2.33
#
# ------------------------------------------
#
# TITLE:
# العراق يطلق مشروعاً وطنياً للتشجير وسط ارتفاع درجات الحرارة
#
# CAPTION:
# ...
